# %%
# Forest Cover Type Prediction - Initial EDA
# ==========================================

# 1) Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configs
pd.set_option("display.max_columns", None)
sns.set(style="whitegrid")

# %%
# 2) Load dataset
# (ajusta la ruta según tu carpeta)
df = pd.read_csv("train.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # 2) Load dataset
#       2 # (ajusta la ruta según tu carpeta)
# ----> 3 df = pd.read_csv("train.csv")
#
# File c:\Users\JeanContreras\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\JeanContreras\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\JeanContreras\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\JeanContreras\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\JeanContreras\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.csv'

# %%
# 3) Quick overview
print("\n🔎 Shape of dataset:", df.shape)
print("\n📌 Columns:", df.columns.tolist())
print("\n🔎 Info:")
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 3) Quick overview
# ----> 2 print("\n🔎 Shape of dataset:", df.shape)
#       3 print("\n📌 Columns:", df.columns.tolist())
#       4 print("\n🔎 Info:")
#
# NameError: name 'df' is not defined

# %%
# 4) First rows
print("\n👀 First rows:")
print(df.head())
# Out:
# 👀 First rows:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # 4) First rows
#       2 print("\n👀 First rows:")
# ----> 3 print(df.head())
#
# NameError: name 'df' is not defined

# %%
# 5) Summary statistics
print("\n📊 Descriptive statistics:")
print(df.describe().T)
# Out:
# 📊 Descriptive statistics:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # 5) Summary statistics
#       2 print("\n📊 Descriptive statistics:")
# ----> 3 print(df.describe().T)
#
# NameError: name 'df' is not defined

# %%
# 6) Missing values check
print("\n❌ Missing values per column:")
print(df.isnull().sum())
# Out:
# ❌ Missing values per column:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # 6) Missing values check
#       2 print("\n❌ Missing values per column:")
# ----> 3 print(df.isnull().sum())
#
# NameError: name 'df' is not defined

# %%
# 7) Target variable distribution
print("\n🎯 Target distribution (Cover_Type):")
print(df['Cover_Type'].value_counts(normalize=True))
plt.figure(figsize=(8,5))
sns.countplot(x='Cover_Type', data=df, palette="viridis")
plt.title("Distribution of Cover_Type")
plt.show()
# Out:
# 🎯 Target distribution (Cover_Type):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # 7) Target variable distribution
#       2 print("\n🎯 Target distribution (Cover_Type):")
# ----> 3 print(df['Cover_Type'].value_counts(normalize=True))
#
# NameError: name 'df' is not defined

# %%
# 8) Numeric features correlation
numeric_features = df.select_dtypes(include=[np.number]).columns.tolist()
corr = df[numeric_features].corr()

plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("Correlation heatmap (numeric features)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 8) Numeric features correlation
# ----> 2 numeric_features = df.select_dtypes(include=[np.number]).columns.tolist()
#       3 corr = df[numeric_features].corr()
#       5 plt.figure(figsize=(12,8))
#
# NameError: name 'df' is not defined

# %%
# 9) Top correlations with Cover_Type
print("\n🔗 Correlation with target (Cover_Type):")
print(corr['Cover_Type'].sort_values(ascending=False).head(15))
# Out:
# 🔗 Correlation with target (Cover_Type):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # 9) Top correlations with Cover_Type
#       2 print("\n🔗 Correlation with target (Cover_Type):")
# ----> 3 print(corr['Cover_Type'].sort_values(ascending=False).head(15))
#
# NameError: name 'corr' is not defined

# %%
# 10) Example univariate plots
plt.figure(figsize=(8,5))
sns.histplot(df['Elevation'], bins=40, kde=True)
plt.title("Elevation distribution")
plt.show()


plt.figure(figsize=(8,5))
sns.histplot(df['Slope'], bins=40, kde=True)
plt.title("Slope distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # 10) Example univariate plots
#       2 plt.figure(figsize=(8,5))
# ----> 3 sns.histplot(df['Elevation'], bins=40, kde=True)
#       4 plt.title("Elevation distribution")
#       5 plt.show()
#
# NameError: name 'df' is not defined

# %%
# 11) Example categorical feature distribution
soil_cols = [col for col in df.columns if "Soil_Type" in col]
print("\n🪨 Soil type columns:", soil_cols[:10], "...")

soil_sums = df[soil_cols].sum().sort_values(ascending=False)
plt.figure(figsize=(12,6))
soil_sums.plot(kind="bar")
plt.title("Soil Type Frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 11) Example categorical feature distribution
# ----> 2 soil_cols = [col for col in df.columns if "Soil_Type" in col]
#       3 print("\n🪨 Soil type columns:", soil_cols[:10], "...")
#       5 soil_sums = df[soil_cols].sum().sort_values(ascending=False)
#
# NameError: name 'df' is not defined

# %%
# 12) Pairplot (optional: only a few vars for speed)
sampled = df.sample(2000, random_state=42)
sns.pairplot(sampled[['Elevation','Slope','Horizontal_Distance_To_Hydrology','Cover_Type']], hue="Cover_Type")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # 12) Pairplot (optional: only a few vars for speed)
# ----> 2 sampled = df.sample(2000, random_state=42)
#       3 sns.pairplot(sampled[['Elevation','Slope','Horizontal_Distance_To_Hydrology','Cover_Type']], hue="Cover_Type")
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
# 13) Save processed EDA summary
summary = {
    "shape": df.shape,
    "columns": df.columns.tolist(),
    "target_distribution": df['Cover_Type'].value_counts().to_dict()
}
pd.Series(summary).to_json("../docs/eda_summary.json")

print("\n✅ EDA complete. Results saved to ../docs/eda_summary.json")
